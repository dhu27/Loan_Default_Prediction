# %% [markdown]
# # Loan Default Prediction Project
#
# This project explores patterns, correlations, and risk indicators associated with loan default behavior using a filtered LendingClub-style loan dataset. The notebook performs a structured exploratory data analysis to understand which borrower attributes are most associated with default outcomes.

# %% [markdown]
# ## Modeling Approach
#
# We developed a binary classification model using sklearn logistic regression, a gradient-boosted decision tree algorithm optimized for speed and performance on large tabular datasets. LightGBM was selected for its ability to:
# * Handle heterogeneous, non-linear relationships
# * Work well with 50-100+ features
# * Manage class imbalance through built-in weighting
# * The target variable is loan_status (0 = fully paid, 1 = default).

# %% [markdown]
# ### Libraries Import

# %%
# Data handling
import pandas as pd
import numpy as np

# Preprocessing
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder 
from sklearn.feature_selection import SelectKBest, mutual_info_classif, VarianceThreshold
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Models
from sklearn.linear_model import LogisticRegression

# Metrics
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, roc_curve, confusion_matrix, classification_report
)

# %% [markdown]
# ### Data Import

# %%
df = pd.read_csv("../filtered.csv")
df.dropna(inplace = True)

# %% [markdown]
# ### Feature Engineering
#
# In addition to some formating changes regarding time, I opted to create some useful features for both organizational purposes as well as model training. I averaged out the fico ranges, created various ratios with income, and built a simple delinquency scores as well as a delinquency flag. More specific descriptions of other engineered features are within the comments in the cell below.

# %%
#term
df['term'] = df['term'].astype(str).str.extract(r'(\d+)').astype(float)

#interest rate
df['int_rate'].astype(str).str.rstrip('%').replace('', np.nan).astype(float)

#emp_length
s = df['emp_length'].astype(str)
#< 1 year 
s = s.str.replace(r'[^0-9]+', '', regex = True)
df['emp_length'] = pd.to_numeric(s, errors = 'coerce')
df['emp_length'] = df['emp_length'].fillna(0).clip(lower = 0, upper = 10)

#issue date
df['issue_d'] = pd.to_datetime(df['issue_d'], format="%b-%Y", errors='coerce')
df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], format="%b-%Y", errors='coerce')

# Credit history length (in years) using months diff for accuracy
mask = df['issue_d'].notna() & df['earliest_cr_line'].notna()
df['credit_history_length'] = np.nan  # init

# months difference, then convert to years
months_diff = (df.loc[mask, 'issue_d'].dt.year - df.loc[mask, 'earliest_cr_line'].dt.year) * 12 + \
              (df.loc[mask, 'issue_d'].dt.month - df.loc[mask, 'earliest_cr_line'].dt.month)
df.loc[mask, 'credit_history_length'] = (months_diff / 12).astype(float)

#feature engineering
df['fico_avg'] = df[['fico_range_low', 'fico_range_high']].mean(axis = 1)

#zip code
df['zip3'] = df['zip_code'].astype(str).str[:3]
df.drop(columns = ['zip_code'], inplace = True)

#Drop original columns
drop_list = ['loan_status', 'fico_range_low', 'fico_range_high', 'earliest_cr_line', 'issue_d']
df.drop(columns = drop_list, inplace = True)

# 1. Installment burden relative to monthly income
df["installment_to_income"] = df["installment"] / (df["annual_inc"] / 12 + 1e-6)

# 2. Loan amount relative to annual income
df["loan_to_income"] = df["loan_amnt"] / (df["annual_inc"] + 1e-6)

# 3. Revolving balance relative to income
df["revol_bal_to_income"] = df["revol_bal"] / (df["annual_inc"] + 1e-6)

# 4. Revolving balance relative to total revolving high credit limit
df["revol_ratio"] = df["revol_bal"] / (df["total_rev_hi_lim"] + 1e-6)

# 5. High utilization flag (very high revolving utilization)
df["high_util_flag"] = (df["revol_util"] > 80).astype(int)

# 6. Weighted delinquency score (more weight for more severe delinquencies)
df["recent_delinquency_score"] = (
    df["num_tl_30dpd"] +
    2 * df["num_tl_90g_dpd_24m"] +
    3 * df["num_accts_ever_120_pd"]
)

# 7. Simple "ever delinquent" flag
df["ever_delinquent_flag"] = (
    (df["delinq_2yrs"] > 0) |
    (df["num_tl_30dpd"] > 0) |
    (df["num_tl_90g_dpd_24m"] > 0) |
    (df["num_accts_ever_120_pd"] > 0)
).astype(int)

# 8. Share of accounts that are installment loans
df["installment_loan_ratio"] = df["num_il_tl"] / (df["total_acc"] + 1e-6)

# 9. Share of accounts that are revolving
df["revolving_loan_ratio"] = df["num_rev_accts"] / (df["total_acc"] + 1e-6)

# 10. Total balance (ex mortgage) vs total high credit limit
df["total_bal_over_high"] = df["total_bal_ex_mort"] / (df["tot_hi_cred_lim"] + 1e-6)

# 11. Current balance vs total high credit limit
df["total_cur_bal_ratio"] = df["tot_cur_bal"] / (df["tot_hi_cred_lim"] + 1e-6)

# 12. FICO bucket (categorical risk bands)
df["fico_bucket"] = pd.cut(
    df["fico_avg"],
    bins=[0, 640, 680, 720, 760, 900],
    labels=[1, 2, 3, 4, 5]
)

# %% [markdown]
# ### Train Test Split

# %%
X = df.drop(columns = ['outcome']) 
y = df['outcome'] 

X_train, x_test, y_train, y_test = train_test_split(X, y, test_size = .25, random_state = 30)

cat_cols = X.select_dtypes(include=['object', 'category']).columns
num_cols = X.select_dtypes(exclude=['object', 'category']).columns

# %% [markdown]
# ### Modeling
#
# My pipeline consists of 4 main components:
# * One-hot encode categorical variables with controls on rare and high-cardinality categories to keep the feature space efficient and stable.
# * Remove low-variance features to eliminate uninformative predictors created during encoding.
# * Select the top 200 features using mutual information to reduce dimensionality and focus on the most predictive signals.
# * Train a logistic regression model with L2 regularization and class_weight="balanced" to handle class imbalance and produce calibrated probabilities.
#
# And then an end-to-end pipeline to ensure consistent preprocessing

# %%
#Modeling
ohe = OneHotEncoder(
    handle_unknown = "ignore",
    sparse_output = True,
    min_frequency = 1000,
    max_categories = 50)

preprocess = ColumnTransformer(
    transformers=[
        ("num", "passthrough", num_cols),
        ("cat", ohe, cat_cols),
    ]
)

nzv = VarianceThreshold(threshold = 1e-5)

selector = SelectKBest(mutual_info_classif, k = 50)

logit = LogisticRegression(solver = "saga",
                           penalty = "l2",
                           max_iter = 1000,
                           class_weight = "balanced",
                           verbose = 1)

from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE


pipe = Pipeline(steps = [
    ("encoding", ohe),
    ("nzv", nzv),
    ("kbest", selector),
    ("model", logit)])

# %%
pipe.fit(X_train, y_train)
# Out:
# Epoch 1, change: 1.00000000
# Epoch 2, change: 0.47393380
# Epoch 3, change: 0.26401383
# Epoch 4, change: 0.20883194
# Epoch 5, change: 0.16764044
# Epoch 6, change: 0.13639280
# Epoch 7, change: 0.09404495
# Epoch 8, change: 0.03884402
# Epoch 9, change: 0.03324460
# Epoch 10, change: 0.03007730
# Epoch 11, change: 0.01723062
# Epoch 12, change: 0.00932272
# Epoch 13, change: 0.00700648
# Epoch 14, change: 0.00729282
# Epoch 15, change: 0.00552663
# Epoch 16, change: 0.00488580
# Epoch 17, change: 0.00430526
# Epoch 18, change: 0.00375261
# Epoch 19, change: 0.00340069
# Epoch 20, change: 0.00304295
# Epoch 21, change: 0.00275291
# Epoch 22, change: 0.00248463
# Epoch 23, change: 0.00226285
# Epoch 24, change: 0.00202310
# Epoch 25, change: 0.00185319
# Epoch 26, change: 0.00166277
# Epoch 27, change: 0.00152103
# Epoch 28, change: 0.00135190
# Epoch 29, change: 0.00124085
# Epoch 30, change: 0.00109822
# Epoch 31, change: 0.00100544
# Epoch 32, change: 0.00091584
# Epoch 33, change: 0.00083276
# Epoch 34, change: 0.00073799
# Epoch 35, change: 0.00067161
# Epoch 36, change: 0.00060781
# Epoch 37, change: 0.00055054
# Epoch 38, change: 0.00049653
# Epoch 39, change: 0.00045040
# Epoch 40, change: 0.00041056
# Epoch 41, change: 0.00038096
# Epoch 42, change: 0.00038038
# Epoch 43, change: 0.00037977
# Epoch 44, change: 0.00037919
# Epoch 45, change: 0.00037858
# Epoch 46, change: 0.00037798
# Epoch 47, change: 0.00037703
# Epoch 48, change: 0.00037721
# Epoch 49, change: 0.00037620
# Epoch 50, change: 0.00037559
# Epoch 51, change: 0.00037501
# Epoch 52, change: 0.00037446
# Epoch 53, change: 0.00037384
# Epoch 54, change: 0.00037324
# Epoch 55, change: 0.00037265
# Epoch 56, change: 0.00037205
# Epoch 57, change: 0.00037147
# Epoch 58, change: 0.00037088
# Epoch 59, change: 0.00037030
# Epoch 60, change: 0.00036971
# Epoch 61, change: 0.00036913
# Epoch 62, change: 0.00036855
# Epoch 63, change: 0.00036796
# Epoch 64, change: 0.00036739
# Epoch 65, change: 0.00036680
# Epoch 66, change: 0.00036623
# Epoch 67, change: 0.00036564
# Epoch 68, change: 0.00036507
# Epoch 69, change: 0.00036449
# Epoch 70, change: 0.00036392
# Epoch 71, change: 0.00036333
# Epoch 72, change: 0.00036277
# Epoch 73, change: 0.00036220
# Epoch 74, change: 0.00036162
# Epoch 75, change: 0.00036105
# Epoch 76, change: 0.00036048
# Epoch 77, change: 0.00035992
# Epoch 78, change: 0.00035934
# Epoch 79, change: 0.00035877
# Epoch 80, change: 0.00035822
# Epoch 81, change: 0.00035764
# Epoch 82, change: 0.00035709
# Epoch 83, change: 0.00035652
# Epoch 84, change: 0.00035596
# Epoch 85, change: 0.00035540
# Epoch 86, change: 0.00035483
# Epoch 87, change: 0.00035428
# Epoch 88, change: 0.00035371
# Epoch 89, change: 0.00035316
# Epoch 90, change: 0.00035260
# Epoch 91, change: 0.00035205
# Epoch 92, change: 0.00035149
# Epoch 93, change: 0.00035094
# Epoch 94, change: 0.00035038
# Epoch 95, change: 0.00034984
# Epoch 96, change: 0.00034928
# Epoch 97, change: 0.00034872
# Epoch 98, change: 0.00034818
# Epoch 99, change: 0.00034762
# Epoch 100, change: 0.00034708
# Epoch 101, change: 0.00034653
# Epoch 102, change: 0.00034598
# Epoch 103, change: 0.00034544
# Epoch 104, change: 0.00034489
# Epoch 105, change: 0.00034435
# Epoch 106, change: 0.00034380
# Epoch 107, change: 0.00034326
# Epoch 108, change: 0.00034272
# Epoch 109, change: 0.00034217
# Epoch 110, change: 0.00034164
# Epoch 111, change: 0.00034110
# Epoch 112, change: 0.00034055
# Epoch 113, change: 0.00034002
# Epoch 114, change: 0.00033948
# Epoch 115, change: 0.00033895
# Epoch 116, change: 0.00033842
# Epoch 117, change: 0.00033787
# Epoch 118, change: 0.00033735
# Epoch 119, change: 0.00033681
# Epoch 120, change: 0.00033628
# Epoch 121, change: 0.00033575
# Epoch 122, change: 0.00033522
# Epoch 123, change: 0.00033470
# Epoch 124, change: 0.00033417
# Epoch 125, change: 0.00033364
# Epoch 126, change: 0.00033311
# Epoch 127, change: 0.00033259
# Epoch 128, change: 0.00033206
# Epoch 129, change: 0.00033153
# Epoch 130, change: 0.00033101
# Epoch 131, change: 0.00033049
# Epoch 132, change: 0.00032997
# Epoch 133, change: 0.00032945
# Epoch 134, change: 0.00032893
# Epoch 135, change: 0.00032841
# Epoch 136, change: 0.00032790
# Epoch 137, change: 0.00032737
# Epoch 138, change: 0.00032685
# Epoch 139, change: 0.00032634
# Epoch 140, change: 0.00032583
# Epoch 141, change: 0.00032531
# Epoch 142, change: 0.00032480
# Epoch 143, change: 0.00032428
# Epoch 144, change: 0.00032378
# Epoch 145, change: 0.00032326
# Epoch 146, change: 0.00032275
# Epoch 147, change: 0.00032224
# Epoch 148, change: 0.00032174
# Epoch 149, change: 0.00032123
# Epoch 150, change: 0.00032072
# Epoch 151, change: 0.00032021
# Epoch 152, change: 0.00031972
# Epoch 153, change: 0.00031920
# Epoch 154, change: 0.00031870
# Epoch 155, change: 0.00031820
# Epoch 156, change: 0.00031770
# Epoch 157, change: 0.00031719
# Epoch 158, change: 0.00031669
# Epoch 159, change: 0.00031620
# Epoch 160, change: 0.00031569
# Epoch 161, change: 0.00031520
# Epoch 162, change: 0.00031470
# Epoch 163, change: 0.00031420
# Epoch 164, change: 0.00031371
# Epoch 165, change: 0.00031322
# Epoch 166, change: 0.00031271
# Epoch 167, change: 0.00031222
# Epoch 168, change: 0.00031173
# Epoch 169, change: 0.00031123
# Epoch 170, change: 0.00031075
# Epoch 171, change: 0.00031026
# Epoch 172, change: 0.00030976
# Epoch 173, change: 0.00030928
# Epoch 174, change: 0.00030879
# Epoch 175, change: 0.00030830
# Epoch 176, change: 0.00030781
# Epoch 177, change: 0.00030733
# Epoch 178, change: 0.00030685
# Epoch 179, change: 0.00030636
# Epoch 180, change: 0.00030588
# Epoch 181, change: 0.00030540
# Epoch 182, change: 0.00030491
# Epoch 183, change: 0.00030443
# Epoch 184, change: 0.00030395
# Epoch 185, change: 0.00030347
# Epoch 186, change: 0.00030299
# Epoch 187, change: 0.00030251
# Epoch 188, change: 0.00030204
# Epoch 189, change: 0.00030156
# Epoch 190, change: 0.00030109
# Epoch 191, change: 0.00030062
# Epoch 192, change: 0.00030013
# Epoch 193, change: 0.00029966
# Epoch 194, change: 0.00029918
# Epoch 195, change: 0.00029872
# Epoch 196, change: 0.00029824
# Epoch 197, change: 0.00029777
# Epoch 198, change: 0.00029730
# Epoch 199, change: 0.00029683
# Epoch 200, change: 0.00029637
# Epoch 201, change: 0.00029590
# Epoch 202, change: 0.00029544
# Epoch 203, change: 0.00029497
# Epoch 204, change: 0.00029450
# Epoch 205, change: 0.00029403
# Epoch 206, change: 0.00029358
# Epoch 207, change: 0.00029310
# Epoch 208, change: 0.00029264
# Epoch 209, change: 0.00029218
# Epoch 210, change: 0.00029172
# Epoch 211, change: 0.00029126
# Epoch 212, change: 0.00029081
# Epoch 213, change: 0.00029034
# Epoch 214, change: 0.00028988
# Epoch 215, change: 0.00028943
# Epoch 216, change: 0.00028897
# Epoch 217, change: 0.00028851
# Epoch 218, change: 0.00028806
# Epoch 219, change: 0.00028761
# Epoch 220, change: 0.00028715
# Epoch 221, change: 0.00028670
# Epoch 222, change: 0.00028624
# Epoch 223, change: 0.00028579
# Epoch 224, change: 0.00028534
# Epoch 225, change: 0.00028489
# Epoch 226, change: 0.00028444
# Epoch 227, change: 0.00028400
# Epoch 228, change: 0.00028355
# Epoch 229, change: 0.00028309
# Epoch 230, change: 0.00028265
# Epoch 231, change: 0.00028220
# Epoch 232, change: 0.00028176
# Epoch 233, change: 0.00028131
# Epoch 234, change: 0.00028087
# Epoch 235, change: 0.00028043
# Epoch 236, change: 0.00027998
# Epoch 237, change: 0.00027954
# Epoch 238, change: 0.00027910
# Epoch 239, change: 0.00027867
# Epoch 240, change: 0.00027822
# Epoch 241, change: 0.00027779
# Epoch 242, change: 0.00027734
# Epoch 243, change: 0.00027691
# Epoch 244, change: 0.00027647
# Epoch 245, change: 0.00027603
# Epoch 246, change: 0.00027560
# Epoch 247, change: 0.00027516
# Epoch 248, change: 0.00027473
# Epoch 249, change: 0.00027429
# Epoch 250, change: 0.00027386
# Epoch 251, change: 0.00027343
# Epoch 252, change: 0.00027300
# Epoch 253, change: 0.00027256
# Epoch 254, change: 0.00027214
# Epoch 255, change: 0.00027171
# Epoch 256, change: 0.00027128
# Epoch 257, change: 0.00027085
# Epoch 258, change: 0.00027042
# Epoch 259, change: 0.00026999
# Epoch 260, change: 0.00026957
# Epoch 261, change: 0.00026914
# Epoch 262, change: 0.00026872
# Epoch 263, change: 0.00026829
# Epoch 264, change: 0.00026787
# Epoch 265, change: 0.00026745
# Epoch 266, change: 0.00026703
# Epoch 267, change: 0.00026661
# Epoch 268, change: 0.00026618
# Epoch 269, change: 0.00026577
# Epoch 270, change: 0.00026534
# Epoch 271, change: 0.00026493
# Epoch 272, change: 0.00026451
# Epoch 273, change: 0.00026409
# Epoch 274, change: 0.00026367
# Epoch 275, change: 0.00026326
# Epoch 276, change: 0.00026285
# Epoch 277, change: 0.00026242
# Epoch 278, change: 0.00026201
# Epoch 279, change: 0.00026160
# Epoch 280, change: 0.00026118
# Epoch 281, change: 0.00026077
# Epoch 282, change: 0.00026037
# Epoch 283, change: 0.00025995
# Epoch 284, change: 0.00025954
# Epoch 285, change: 0.00025913
# Epoch 286, change: 0.00025872
# Epoch 287, change: 0.00025831
# Epoch 288, change: 0.00025790
# Epoch 289, change: 0.00025750
# Epoch 290, change: 0.00025709
# Epoch 291, change: 0.00025669
# Epoch 292, change: 0.00025629
# Epoch 293, change: 0.00025587
# Epoch 294, change: 0.00025548
# Epoch 295, change: 0.00025507
# Epoch 296, change: 0.00025467
# Epoch 297, change: 0.00025427
# Epoch 298, change: 0.00025386
# Epoch 299, change: 0.00025347
# Epoch 300, change: 0.00025306
# Epoch 301, change: 0.00025267
# Epoch 302, change: 0.00025227
# Epoch 303, change: 0.00025187
# Epoch 304, change: 0.00025147
# Epoch 305, change: 0.00025107
# Epoch 306, change: 0.00025068
# Epoch 307, change: 0.00025028
# Epoch 308, change: 0.00024989
# Epoch 309, change: 0.00024950
# Epoch 310, change: 0.00024910
# Epoch 311, change: 0.00024871
# Epoch 312, change: 0.00024831
# Epoch 313, change: 0.00024792
# Epoch 314, change: 0.00024754
# Epoch 315, change: 0.00024714
# Epoch 316, change: 0.00024675
# Epoch 317, change: 0.00024636
# Epoch 318, change: 0.00024597
# Epoch 319, change: 0.00024559
# Epoch 320, change: 0.00024520
# Epoch 321, change: 0.00024480
# Epoch 322, change: 0.00024443
# Epoch 323, change: 0.00024404
# Epoch 324, change: 0.00024365
# Epoch 325, change: 0.00024327
# Epoch 326, change: 0.00024288
# Epoch 327, change: 0.00024250
# Epoch 328, change: 0.00024211
# Epoch 329, change: 0.00024174
# Epoch 330, change: 0.00024136
# Epoch 331, change: 0.00024097
# Epoch 332, change: 0.00024059
# Epoch 333, change: 0.00024022
# Epoch 334, change: 0.00023983
# Epoch 335, change: 0.00023946
# Epoch 336, change: 0.00023908
# Epoch 337, change: 0.00023870
# Epoch 338, change: 0.00023832
# Epoch 339, change: 0.00023795
# Epoch 340, change: 0.00023757
# Epoch 341, change: 0.00023719
# Epoch 342, change: 0.00023682
# Epoch 343, change: 0.00023645
# Epoch 344, change: 0.00023608
# Epoch 345, change: 0.00023570
# Epoch 346, change: 0.00023533
# Epoch 347, change: 0.00023496
# Epoch 348, change: 0.00023459
# Epoch 349, change: 0.00023422
# Epoch 350, change: 0.00023385
# Epoch 351, change: 0.00023348
# Epoch 352, change: 0.00023311
# Epoch 353, change: 0.00023274
# Epoch 354, change: 0.00023237
# Epoch 355, change: 0.00023201
# Epoch 356, change: 0.00023164
# Epoch 357, change: 0.00023128
# Epoch 358, change: 0.00023091
# Epoch 359, change: 0.00023055
# Epoch 360, change: 0.00023018
# Epoch 361, change: 0.00022982
# Epoch 362, change: 0.00022946
# Epoch 363, change: 0.00022910
# Epoch 364, change: 0.00022873
# Epoch 365, change: 0.00022837
# Epoch 366, change: 0.00022801
# Epoch 367, change: 0.00022765
# Epoch 368, change: 0.00022729
# Epoch 369, change: 0.00022693
# Epoch 370, change: 0.00022658
# Epoch 371, change: 0.00022622
# Epoch 372, change: 0.00022586
# Epoch 373, change: 0.00022551
# Epoch 374, change: 0.00022515
# Epoch 375, change: 0.00022479
# Epoch 376, change: 0.00022444
# Epoch 377, change: 0.00022409
# Epoch 378, change: 0.00022373
# Epoch 379, change: 0.00022338
# Epoch 380, change: 0.00022302
# Epoch 381, change: 0.00022267
# Epoch 382, change: 0.00022232
# Epoch 383, change: 0.00022198
# Epoch 384, change: 0.00022162
# Epoch 385, change: 0.00022127
# Epoch 386, change: 0.00022093
# Epoch 387, change: 0.00022057
# Epoch 388, change: 0.00022022
# Epoch 389, change: 0.00021988
# Epoch 390, change: 0.00021953
# Epoch 391, change: 0.00021918
# Epoch 392, change: 0.00021884
# Epoch 393, change: 0.00021849
# Epoch 394, change: 0.00021815
# Epoch 395, change: 0.00021780
# Epoch 396, change: 0.00021746
# Epoch 397, change: 0.00021712
# Epoch 398, change: 0.00021677
# Epoch 399, change: 0.00021643
# Epoch 400, change: 0.00021609
# Epoch 401, change: 0.00021575
# Epoch 402, change: 0.00021541
# Epoch 403, change: 0.00021507
# Epoch 404, change: 0.00021473
# Epoch 405, change: 0.00021439
# Epoch 406, change: 0.00021406
# Epoch 407, change: 0.00021372
# Epoch 408, change: 0.00021338
# Epoch 409, change: 0.00021304
# Epoch 410, change: 0.00021271
# Epoch 411, change: 0.00021237
# Epoch 412, change: 0.00021204
# Epoch 413, change: 0.00021170
# Epoch 414, change: 0.00021137
# Epoch 415, change: 0.00021103
# Epoch 416, change: 0.00021070
# Epoch 417, change: 0.00021037
# Epoch 418, change: 0.00021003
# Epoch 419, change: 0.00020970
# Epoch 420, change: 0.00020937
# Epoch 421, change: 0.00020905
# Epoch 422, change: 0.00020871
# Epoch 423, change: 0.00020838
# Epoch 424, change: 0.00020805
# Epoch 425, change: 0.00020772
# Epoch 426, change: 0.00020740
# Epoch 427, change: 0.00020707
# Epoch 428, change: 0.00020674
# Epoch 429, change: 0.00020642
# Epoch 430, change: 0.00020609
# Epoch 431, change: 0.00020576
# Epoch 432, change: 0.00020544
# Epoch 433, change: 0.00020511
# Epoch 434, change: 0.00020479
# Epoch 435, change: 0.00020447
# Epoch 436, change: 0.00020414
# Epoch 437, change: 0.00020383
# Epoch 438, change: 0.00020350
# Epoch 439, change: 0.00020319
# Epoch 440, change: 0.00020286
# Epoch 441, change: 0.00020255
# Epoch 442, change: 0.00020222
# Epoch 443, change: 0.00020190
# Epoch 444, change: 0.00020158
# Epoch 445, change: 0.00020127
# Epoch 446, change: 0.00020095
# Epoch 447, change: 0.00020063
# Epoch 448, change: 0.00020031
# Epoch 449, change: 0.00020000
# Epoch 450, change: 0.00019968
# Epoch 451, change: 0.00019936
# Epoch 452, change: 0.00019905
# Epoch 453, change: 0.00019874
# Epoch 454, change: 0.00019843
# Epoch 455, change: 0.00019811
# Epoch 456, change: 0.00019780
# Epoch 457, change: 0.00019749
# Epoch 458, change: 0.00019717
# Epoch 459, change: 0.00019686
# Epoch 460, change: 0.00019655
# Epoch 461, change: 0.00019624
# Epoch 462, change: 0.00019593
# Epoch 463, change: 0.00019562
# Epoch 464, change: 0.00019532
# Epoch 465, change: 0.00019501
# Epoch 466, change: 0.00019470
# Epoch 467, change: 0.00019439
# Epoch 468, change: 0.00019408
# Epoch 469, change: 0.00019378
# Epoch 470, change: 0.00019347
# Epoch 471, change: 0.00019317
# Epoch 472, change: 0.00019287
# Epoch 473, change: 0.00019256
# Epoch 474, change: 0.00019227
# Epoch 475, change: 0.00019195
# Epoch 476, change: 0.00019164
# Epoch 477, change: 0.00019135
# Epoch 478, change: 0.00019104
# Epoch 479, change: 0.00019074
# Epoch 480, change: 0.00019044
# Epoch 481, change: 0.00019014
# Epoch 482, change: 0.00018984
# Epoch 483, change: 0.00018954
# Epoch 484, change: 0.00018924
# Epoch 485, change: 0.00018894
# Epoch 486, change: 0.00018864
# Epoch 487, change: 0.00018835
# Epoch 488, change: 0.00018805
# Epoch 489, change: 0.00018775
# Epoch 490, change: 0.00018746
# Epoch 491, change: 0.00018716
# Epoch 492, change: 0.00018687
# Epoch 493, change: 0.00018657
# Epoch 494, change: 0.00018628
# Epoch 495, change: 0.00018598
# Epoch 496, change: 0.00018569
# Epoch 497, change: 0.00018539
# Epoch 498, change: 0.00018510
# Epoch 499, change: 0.00018481
# Epoch 500, change: 0.00018452
# Epoch 501, change: 0.00018423
# Epoch 502, change: 0.00018394
# Epoch 503, change: 0.00018365
# Epoch 504, change: 0.00018335
# Epoch 505, change: 0.00018307
# Epoch 506, change: 0.00018278
# Epoch 507, change: 0.00018249
# Epoch 508, change: 0.00018220
# Epoch 509, change: 0.00018191
# Epoch 510, change: 0.00018163
# Epoch 511, change: 0.00018134
# Epoch 512, change: 0.00018105
# Epoch 513, change: 0.00018077
# Epoch 514, change: 0.00018048
# Epoch 515, change: 0.00018020
# Epoch 516, change: 0.00017991
# Epoch 517, change: 0.00017963
# Epoch 518, change: 0.00017934
# Epoch 519, change: 0.00017907
# Epoch 520, change: 0.00017878
# Epoch 521, change: 0.00017850
# Epoch 522, change: 0.00017822
# Epoch 523, change: 0.00017793
# Epoch 524, change: 0.00017766
# Epoch 525, change: 0.00017738
# Epoch 526, change: 0.00017710
# Epoch 527, change: 0.00017681
# Epoch 528, change: 0.00017654
# Epoch 529, change: 0.00017626
# Epoch 530, change: 0.00017598
# Epoch 531, change: 0.00017570
# Epoch 532, change: 0.00017542
# Epoch 533, change: 0.00017515
# Epoch 534, change: 0.00017487
# Epoch 535, change: 0.00017460
# Epoch 536, change: 0.00017432
# Epoch 537, change: 0.00017405
# Epoch 538, change: 0.00017377
# Epoch 539, change: 0.00017350
# Epoch 540, change: 0.00017322
# Epoch 541, change: 0.00017295
# Epoch 542, change: 0.00017268
# Epoch 543, change: 0.00017241
# Epoch 544, change: 0.00017213
# Epoch 545, change: 0.00017186
# Epoch 546, change: 0.00017159
# Epoch 547, change: 0.00017132
# Epoch 548, change: 0.00017105
# Epoch 549, change: 0.00017077
# Epoch 550, change: 0.00017051
# Epoch 551, change: 0.00017024
# Epoch 552, change: 0.00016997
# Epoch 553, change: 0.00016970
# Epoch 554, change: 0.00016944
# Epoch 555, change: 0.00016917
# Epoch 556, change: 0.00016890
# Epoch 557, change: 0.00016864
# Epoch 558, change: 0.00016837
# Epoch 559, change: 0.00016810
# Epoch 560, change: 0.00016784
# Epoch 561, change: 0.00016757
# Epoch 562, change: 0.00016731
# Epoch 563, change: 0.00016704
# Epoch 564, change: 0.00016678
# Epoch 565, change: 0.00016652
# Epoch 566, change: 0.00016625
# Epoch 567, change: 0.00016599
# Epoch 568, change: 0.00016573
# Epoch 569, change: 0.00016547
# Epoch 570, change: 0.00016521
# Epoch 571, change: 0.00016495
# Epoch 572, change: 0.00016468
# Epoch 573, change: 0.00016443
# Epoch 574, change: 0.00016416
# Epoch 575, change: 0.00016391
# Epoch 576, change: 0.00016365
# Epoch 577, change: 0.00016340
# Epoch 578, change: 0.00016313
# Epoch 579, change: 0.00016288
# Epoch 580, change: 0.00016262
# Epoch 581, change: 0.00016236
# Epoch 582, change: 0.00016210
# Epoch 583, change: 0.00016185
# Epoch 584, change: 0.00016159
# Epoch 585, change: 0.00016133
# Epoch 586, change: 0.00016108
# Epoch 587, change: 0.00016083
# Epoch 588, change: 0.00016058
# Epoch 589, change: 0.00016032
# Epoch 590, change: 0.00016007
# Epoch 591, change: 0.00015982
# Epoch 592, change: 0.00015957
# Epoch 593, change: 0.00015931
# Epoch 594, change: 0.00015906
# Epoch 595, change: 0.00015881
# Epoch 596, change: 0.00015856
# Epoch 597, change: 0.00015831
# Epoch 598, change: 0.00015806
# Epoch 599, change: 0.00015781
# Epoch 600, change: 0.00015756
# Epoch 601, change: 0.00015731
# Epoch 602, change: 0.00015707
# Epoch 603, change: 0.00015681
# Epoch 604, change: 0.00015657
# Epoch 605, change: 0.00015632
# Epoch 606, change: 0.00015607
# Epoch 607, change: 0.00015583
# Epoch 608, change: 0.00015558
# Epoch 609, change: 0.00015534
# Epoch 610, change: 0.00015509
# Epoch 611, change: 0.00015485
# Epoch 612, change: 0.00015460
# Epoch 613, change: 0.00015436
# Epoch 614, change: 0.00015411
# Epoch 615, change: 0.00015387
# Epoch 616, change: 0.00015363
# Epoch 617, change: 0.00015338
# Epoch 618, change: 0.00015315
# Epoch 619, change: 0.00015290
# Epoch 620, change: 0.00015266
# Epoch 621, change: 0.00015242
# Epoch 622, change: 0.00015219
# Epoch 623, change: 0.00015194
# Epoch 624, change: 0.00015170
# Epoch 625, change: 0.00015146
# Epoch 626, change: 0.00015122
# Epoch 627, change: 0.00015098
# Epoch 628, change: 0.00015074
# Epoch 629, change: 0.00015050
# Epoch 630, change: 0.00015027
# Epoch 631, change: 0.00015003
# Epoch 632, change: 0.00014979
# Epoch 633, change: 0.00014956
# Epoch 634, change: 0.00014932
# Epoch 635, change: 0.00014909
# Epoch 636, change: 0.00014885
# Epoch 637, change: 0.00014862
# Epoch 638, change: 0.00014838
# Epoch 639, change: 0.00014815
# Epoch 640, change: 0.00014791
# Epoch 641, change: 0.00014768
# Epoch 642, change: 0.00014745
# Epoch 643, change: 0.00014722
# Epoch 644, change: 0.00014698
# Epoch 645, change: 0.00014675
# Epoch 646, change: 0.00014652
# Epoch 647, change: 0.00014629
# Epoch 648, change: 0.00014606
# Epoch 649, change: 0.00014582
# Epoch 650, change: 0.00014560
# Epoch 651, change: 0.00014537
# Epoch 652, change: 0.00014513
# Epoch 653, change: 0.00014491
# Epoch 654, change: 0.00014468
# Epoch 655, change: 0.00014445
# Epoch 656, change: 0.00014422
# Epoch 657, change: 0.00014399
# Epoch 658, change: 0.00014377
# Epoch 659, change: 0.00014354
# Epoch 660, change: 0.00014331
# Epoch 661, change: 0.00014309
# Epoch 662, change: 0.00014286
# Epoch 663, change: 0.00014264
# Epoch 664, change: 0.00014241
# Epoch 665, change: 0.00014219
# Epoch 666, change: 0.00014196
# Epoch 667, change: 0.00014174
# Epoch 668, change: 0.00014151
# Epoch 669, change: 0.00014129
# Epoch 670, change: 0.00014107
# Epoch 671, change: 0.00014084
# Epoch 672, change: 0.00014062
# Epoch 673, change: 0.00014040
# Epoch 674, change: 0.00014018
# Epoch 675, change: 0.00013996
# Epoch 676, change: 0.00013974
# Epoch 677, change: 0.00013952
# Epoch 678, change: 0.00013930
# Epoch 679, change: 0.00013908
# Epoch 680, change: 0.00013886
# Epoch 681, change: 0.00013864
# Epoch 682, change: 0.00013842
# Epoch 683, change: 0.00013820
# Epoch 684, change: 0.00013798
# Epoch 685, change: 0.00013776
# Epoch 686, change: 0.00013755
# Epoch 687, change: 0.00013733
# Epoch 688, change: 0.00013711
# Epoch 689, change: 0.00013690
# Epoch 690, change: 0.00013668
# Epoch 691, change: 0.00013646
# Epoch 692, change: 0.00013625
# Epoch 693, change: 0.00013603
# Epoch 694, change: 0.00013582
# Epoch 695, change: 0.00013561
# Epoch 696, change: 0.00013539
# Epoch 697, change: 0.00013518
# Epoch 698, change: 0.00013497
# Epoch 699, change: 0.00013475
# Epoch 700, change: 0.00013454
# Epoch 701, change: 0.00013433
# Epoch 702, change: 0.00013411
# Epoch 703, change: 0.00013390
# Epoch 704, change: 0.00013369
# Epoch 705, change: 0.00013348
# Epoch 706, change: 0.00013327
# Epoch 707, change: 0.00013306
# Epoch 708, change: 0.00013285
# Epoch 709, change: 0.00013264
# Epoch 710, change: 0.00013243
# Epoch 711, change: 0.00013222
# Epoch 712, change: 0.00013201
# Epoch 713, change: 0.00013181
# Epoch 714, change: 0.00013160
# Epoch 715, change: 0.00013139
# Epoch 716, change: 0.00013118
# Epoch 717, change: 0.00013098
# Epoch 718, change: 0.00013077
# Epoch 719, change: 0.00013056
# Epoch 720, change: 0.00013036
# Epoch 721, change: 0.00013015
# Epoch 722, change: 0.00012995
# Epoch 723, change: 0.00012974
# Epoch 724, change: 0.00012954
# Epoch 725, change: 0.00012933
# Epoch 726, change: 0.00012913
# Epoch 727, change: 0.00012893
# Epoch 728, change: 0.00012872
# Epoch 729, change: 0.00012852
# Epoch 730, change: 0.00012831
# Epoch 731, change: 0.00012811
# Epoch 732, change: 0.00012791
# Epoch 733, change: 0.00012771
# Epoch 734, change: 0.00012751
# Epoch 735, change: 0.00012730
# Epoch 736, change: 0.00012710
# Epoch 737, change: 0.00012690
# Epoch 738, change: 0.00012670
# Epoch 739, change: 0.00012650
# Epoch 740, change: 0.00012630
# Epoch 741, change: 0.00012611
# Epoch 742, change: 0.00012591
# Epoch 743, change: 0.00012571
# Epoch 744, change: 0.00012551
# Epoch 745, change: 0.00012531
# Epoch 746, change: 0.00012511
# Epoch 747, change: 0.00012492
# Epoch 748, change: 0.00012472
# Epoch 749, change: 0.00012452
# Epoch 750, change: 0.00012432
# Epoch 751, change: 0.00012413
# Epoch 752, change: 0.00012393
# Epoch 753, change: 0.00012374
# Epoch 754, change: 0.00012354
# Epoch 755, change: 0.00012335
# Epoch 756, change: 0.00012315
# Epoch 757, change: 0.00012296
# Epoch 758, change: 0.00012276
# Epoch 759, change: 0.00012257
# Epoch 760, change: 0.00012238
# Epoch 761, change: 0.00012218
# Epoch 762, change: 0.00012199
# Epoch 763, change: 0.00012180
# Epoch 764, change: 0.00012161
# Epoch 765, change: 0.00012141
# Epoch 766, change: 0.00012122
# Epoch 767, change: 0.00012103
# Epoch 768, change: 0.00012084
# Epoch 769, change: 0.00012065
# Epoch 770, change: 0.00012046
# Epoch 771, change: 0.00012027
# Epoch 772, change: 0.00012008
# Epoch 773, change: 0.00011989
# Epoch 774, change: 0.00011970
# Epoch 775, change: 0.00011951
# Epoch 776, change: 0.00011932
# Epoch 777, change: 0.00011913
# Epoch 778, change: 0.00011895
# Epoch 779, change: 0.00011876
# Epoch 780, change: 0.00011857
# Epoch 781, change: 0.00011838
# Epoch 782, change: 0.00011820
# Epoch 783, change: 0.00011801
# Epoch 784, change: 0.00011782
# Epoch 785, change: 0.00011764
# Epoch 786, change: 0.00011745
# Epoch 787, change: 0.00011727
# Epoch 788, change: 0.00011708
# Epoch 789, change: 0.00011690
# Epoch 790, change: 0.00011671
# Epoch 791, change: 0.00011653
# Epoch 792, change: 0.00011634
# Epoch 793, change: 0.00011616
# Epoch 794, change: 0.00011598
# Epoch 795, change: 0.00011579
# Epoch 796, change: 0.00011561
# Epoch 797, change: 0.00011543
# Epoch 798, change: 0.00011525
# Epoch 799, change: 0.00011506
# Epoch 800, change: 0.00011488
# Epoch 801, change: 0.00011470
# Epoch 802, change: 0.00011452
# Epoch 803, change: 0.00011434
# Epoch 804, change: 0.00011416
# Epoch 805, change: 0.00011398
# Epoch 806, change: 0.00011380
# Epoch 807, change: 0.00011362
# Epoch 808, change: 0.00011344
# Epoch 809, change: 0.00011326
# Epoch 810, change: 0.00011308
# Epoch 811, change: 0.00011290
# Epoch 812, change: 0.00011273
# Epoch 813, change: 0.00011255
# Epoch 814, change: 0.00011237
# Epoch 815, change: 0.00011219
# Epoch 816, change: 0.00011202
# Epoch 817, change: 0.00011184
# Epoch 818, change: 0.00011166
# Epoch 819, change: 0.00011149
# Epoch 820, change: 0.00011131
# Epoch 821, change: 0.00011113
# Epoch 822, change: 0.00011096
# Epoch 823, change: 0.00011079
# Epoch 824, change: 0.00011061
# Epoch 825, change: 0.00011044
# Epoch 826, change: 0.00011026
# Epoch 827, change: 0.00011009
# Epoch 828, change: 0.00010991
# Epoch 829, change: 0.00010974
# Epoch 830, change: 0.00010957
# Epoch 831, change: 0.00010939
# Epoch 832, change: 0.00010922
# Epoch 833, change: 0.00010905
# Epoch 834, change: 0.00010888
# Epoch 835, change: 0.00010870
# Epoch 836, change: 0.00010853
# Epoch 837, change: 0.00010836
# Epoch 838, change: 0.00010819
# Epoch 839, change: 0.00010802
# Epoch 840, change: 0.00010785
# Epoch 841, change: 0.00010768
# Epoch 842, change: 0.00010751
# Epoch 843, change: 0.00010734
# Epoch 844, change: 0.00010717
# Epoch 845, change: 0.00010700
# Epoch 846, change: 0.00010683
# Epoch 847, change: 0.00010666
# Epoch 848, change: 0.00010650
# Epoch 849, change: 0.00010633
# Epoch 850, change: 0.00010616
# Epoch 851, change: 0.00010599
# Epoch 852, change: 0.00010582
# Epoch 853, change: 0.00010566
# Epoch 854, change: 0.00010549
# Epoch 855, change: 0.00010532
# Epoch 856, change: 0.00010516
# Epoch 857, change: 0.00010499
# Epoch 858, change: 0.00010483
# Epoch 859, change: 0.00010466
# Epoch 860, change: 0.00010450
# Epoch 861, change: 0.00010433
# Epoch 862, change: 0.00010417
# Epoch 863, change: 0.00010400
# Epoch 864, change: 0.00010384
# Epoch 865, change: 0.00010367
# Epoch 866, change: 0.00010351
# Epoch 867, change: 0.00010334
# Epoch 868, change: 0.00010318
# Epoch 869, change: 0.00010302
# Epoch 870, change: 0.00010286
# Epoch 871, change: 0.00010270
# Epoch 872, change: 0.00010253
# Epoch 873, change: 0.00010237
# Epoch 874, change: 0.00010221
# Epoch 875, change: 0.00010205
# Epoch 876, change: 0.00010189
# Epoch 877, change: 0.00010172
# Epoch 878, change: 0.00010157
# Epoch 879, change: 0.00010141
# Epoch 880, change: 0.00010125
# Epoch 881, change: 0.00010109
# Epoch 882, change: 0.00010093
# Epoch 883, change: 0.00010077
# Epoch 884, change: 0.00010061
# Epoch 885, change: 0.00010045
# Epoch 886, change: 0.00010029
# Epoch 887, change: 0.00010013
# convergence after 888 epochs took 125 seconds
# Pipeline(steps=[('encoding',
#                  OneHotEncoder(handle_unknown='ignore', max_categories=50,
#                                min_frequency=1000)),
#                 ('nzv', VarianceThreshold(threshold=1e-05)),
#                 ('kbest',
#                  SelectKBest(k=50,
#                              score_func=<function mutual_info_classif at 0x31f591580>)),
#                 ('model',
#                  LogisticRegression(class_weight='balanced', max_iter=1000,
#                                     solver='saga', verbose=1))])

# %%
y_pred = pipe.predict(x_test)
y_proba = pipe.predict_proba(x_test)

# %% [markdown]
# ### Results
#
# My logistic regression model achieves a recall of 0.68 for the default class, indicating that it successfully identifies a substantial majority of borrowers who ultimately default—an essential requirement in credit risk applications where the cost of missing a high-risk borrower is significant. While precision for this class is lower at 0.31, this reflects an intentional and acceptable trade-off, as catching more true defaults naturally increases false positives.

# %%
print("\nClassification report: \n", classification_report(y_test, y_pred))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.62      0.73    200798
#            1       0.31      0.68      0.42     50181
#
#     accuracy                           0.63    250979
#    macro avg       0.60      0.65      0.58    250979
# weighted avg       0.77      0.63      0.67    250979

# %%
print("ROC AUC: ", roc_auc_score(y_test, y_proba[:, 1]))
# Out:
# ROC AUC:  0.7061978389155072
